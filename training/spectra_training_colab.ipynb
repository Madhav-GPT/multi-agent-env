# %% [markdown]
# # SPECTRA Training Notebook
#
# This notebook runs the three required comparison conditions and stores the outputs for the hackathon deliverable.

# %%
# !pip install -r requirements.txt

# %%
from training.grpo_train import run_condition
from eval.metrics import summarize

records_a = run_condition('A', 10, 'mixed')
records_b = run_condition('B', 10, 'mixed')
records_c = run_condition('C', 10, 'mixed')
summaries = {
    'A': summarize(records_a),
    'B': summarize(records_b),
    'C': summarize(records_c),
}
summaries

# %%
from eval.compare_conditions import main
